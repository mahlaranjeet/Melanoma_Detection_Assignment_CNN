# %% [markdown]
# # CNN Model
# # By Dr. Ranjeet Singh Mahla
# # Date April 21, 2023

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of skin cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing the data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib # The pathlib library provides an object-oriented interface for working with files and directories
import tensorflow as tf # tensorflow is a popular open-source machine learning library developed by Google.
import matplotlib.pyplot as plt # matplotlib is a plotting library that allows to create various types of visualizations.
import numpy as np # numpy is a powerful library for working with arrays and matrices
import pandas as pd # pandas is a library that provides high-performance, easy-to-use data structures and data analysis tools for Python.
import os # os provides a way of interacting with the operating system.
import PIL # PIL is a library for working with images.
from glob import glob # 
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
#from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# mounts the Google Drive storage to the Colab notebook instance.
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Motivation: To create a multiclass classification model using a custom convolutional neural network in **tensorflow**

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.
#
# The data set contains the following diseases:
#
# Actinic keratosis
# Basal cell carcinoma
# Dermatofibroma
# Melanoma
# Nevus
# Pigmented benign keratosis
# Seborrheic keratosis
# Squamous cell carcinoma
# Vascular lesion

# %%
# Path to test and train data
root_path = '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration'
data_dir_train = pathlib.Path(root_path + '/Train') # path to trian directory
data_dir_test = pathlib.Path(root_path + '/Test') # path to test directory

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14754 files belonging to 9 classes.
# Using 11804 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 14754 files belonging to 9 classes.
# Using 2950 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# # Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import BatchNormalization

preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]


input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  module_wrapper (ModuleWrapp  (None, 88, 88, 32)       0
#  er)
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 64)        18496
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_1 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_2 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_4 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_6 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 1)                513
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 1)                0
#  pper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss="binary_crossentropy",
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  module_wrapper (ModuleWrapp  (None, 88, 88, 32)       0
#  er)
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 64)        18496
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_1 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_2 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_4 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_6 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 1)                513
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 1)                0
#  pper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 369/369 [==============================] - 107s 111ms/step - loss: -9607178.0000 - accuracy: 0.1595 - val_loss: -28280806.0000 - val_accuracy: 0.1671
# Epoch 2/20
# 369/369 [==============================] - 24s 64ms/step - loss: -129687696.0000 - accuracy: 0.1595 - val_loss: -213596224.0000 - val_accuracy: 0.1671
# Epoch 3/20
# 369/369 [==============================] - 24s 65ms/step - loss: -515379232.0000 - accuracy: 0.1595 - val_loss: -571205184.0000 - val_accuracy: 0.1671
# Epoch 4/20
# 369/369 [==============================] - 25s 68ms/step - loss: -1285933440.0000 - accuracy: 0.1595 - val_loss: -1903593344.0000 - val_accuracy: 0.1671
# Epoch 5/20
# 369/369 [==============================] - 25s 68ms/step - loss: -2537228032.0000 - accuracy: 0.1595 - val_loss: -3289506304.0000 - val_accuracy: 0.1671
# Epoch 6/20
# 369/369 [==============================] - 24s 65ms/step - loss: -4289512192.0000 - accuracy: 0.1595 - val_loss: -3900780288.0000 - val_accuracy: 0.1671
# Epoch 7/20
# 369/369 [==============================] - 24s 65ms/step - loss: -6601688064.0000 - accuracy: 0.1595 - val_loss: -8905021440.0000 - val_accuracy: 0.1671
# Epoch 8/20
# 369/369 [==============================] - 24s 65ms/step - loss: -9513096192.0000 - accuracy: 0.1595 - val_loss: -12060961792.0000 - val_accuracy: 0.1671
# Epoch 9/20
# 369/369 [==============================] - 24s 65ms/step - loss: -13009771520.0000 - accuracy: 0.1595 - val_loss: -14629340160.0000 - val_accuracy: 0.1671
# Epoch 10/20
# 369/369 [==============================] - 24s 66ms/step - loss: -17176088576.0000 - accuracy: 0.1595 - val_loss: -22166921216.0000 - val_accuracy: 0.1671
# Epoch 11/20
# 369/369 [==============================] - 25s 69ms/step - loss: -22047655936.0000 - accuracy: 0.1595 - val_loss: -23087577088.0000 - val_accuracy: 0.1671
# Epoch 12/20
# 369/369 [==============================] - 24s 65ms/step - loss: -27672664064.0000 - accuracy: 0.1595 - val_loss: -27700107264.0000 - val_accuracy: 0.1671
# Epoch 13/20
# 369/369 [==============================] - 24s 65ms/step - loss: -33944928256.0000 - accuracy: 0.1595 - val_loss: -37242241024.0000 - val_accuracy: 0.1671
# Epoch 14/20
# 369/369 [==============================] - 24s 65ms/step - loss: -40902631424.0000 - accuracy: 0.1595 - val_loss: -48372449280.0000 - val_accuracy: 0.1671
# Epoch 15/20
# 369/369 [==============================] - 24s 66ms/step - loss: -48692318208.0000 - accuracy: 0.1595 - val_loss: -44007821312.0000 - val_accuracy: 0.1671
# Epoch 16/20
# 369/369 [==============================] - 24s 66ms/step - loss: -57220128768.0000 - accuracy: 0.1595 - val_loss: -58351804416.0000 - val_accuracy: 0.1671
# Epoch 17/20
# 369/369 [==============================] - 24s 66ms/step - loss: -66695487488.0000 - accuracy: 0.1595 - val_loss: -67655589888.0000 - val_accuracy: 0.1671
# Epoch 18/20
# 369/369 [==============================] - 24s 66ms/step - loss: -76930695168.0000 - accuracy: 0.1595 - val_loss: -71065534464.0000 - val_accuracy: 0.1671
# Epoch 19/20
# 369/369 [==============================] - 24s 65ms/step - loss: -88063426560.0000 - accuracy: 0.1595 - val_loss: -71348199424.0000 - val_accuracy: 0.1671
# Epoch 20/20
# 369/369 [==============================] - 24s 66ms/step - loss: -99965075456.0000 - accuracy: 0.1595 - val_loss: -100657651712.0000 - val_accuracy: 0.1671

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# loss, accuracy = model.evaluate(train_ds, verbose=1,)
# loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)
#
# print("Accuracy: ", accuracy)
# print("Validation Accuracy: ",accuracy_v)
# print("Loss: ",loss)
# print("Validation Loss", loss_v)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# Found 5405 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      9248
#
#  module_wrapper_9 (ModuleWra  (None, 90, 90, 32)       0
#  pper)
#
#  module_wrapper_10 (ModuleWr  (None, 90, 90, 32)       0
#  apper)
#
#  conv2d_6 (Conv2D)           (None, 90, 90, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 64)        36928
#
#  module_wrapper_11 (ModuleWr  (None, 45, 45, 64)       0
#  apper)
#
#  module_wrapper_12 (ModuleWr  (None, 45, 45, 64)       0
#  apper)
#
#  conv2d_8 (Conv2D)           (None, 43, 43, 128)       73856
#
#  module_wrapper_13 (ModuleWr  (None, 21, 21, 128)      0
#  apper)
#
#  module_wrapper_14 (ModuleWr  (None, 21, 21, 128)      0
#  apper)
#
#  module_wrapper_15 (ModuleWr  (None, 56448)            0
#  apper)
#
#  module_wrapper_16 (ModuleWr  (None, 512)              28901888
#  apper)
#
#  module_wrapper_17 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_18 (ModuleWr  (None, 9)                4617
#  apper)
#
# =================================================================
# Total params: 29,045,929
# Trainable params: 29,045,929
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
  epochs = epochs, verbose = 1, validation_data=valid_batches , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 85/85 [==============================] - 168s 2s/step - loss: 33.3809 - accuracy: 0.3828 - val_loss: 1.5147 - val_accuracy: 0.3125 - lr: 0.0010
# Epoch 2/20
# 85/85 [==============================] - 158s 2s/step - loss: 0.8541 - accuracy: 0.6372 - val_loss: 1.2297 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 3/20
# 85/85 [==============================] - 166s 2s/step - loss: 0.7184 - accuracy: 0.7021 - val_loss: 1.1838 - val_accuracy: 0.5208 - lr: 0.0010
# Epoch 4/20
# 85/85 [==============================] - 158s 2s/step - loss: 0.6995 - accuracy: 0.7127 - val_loss: 1.1756 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 5/20
# 85/85 [==============================] - ETA: 0s - loss: 0.6328 - accuracy: 0.7399
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 85/85 [==============================] - 154s 2s/step - loss: 0.6328 - accuracy: 0.7399 - val_loss: 1.1538 - val_accuracy: 0.4375 - lr: 0.0010
# Epoch 6/20
# 85/85 [==============================] - 154s 2s/step - loss: 0.6069 - accuracy: 0.7550 - val_loss: 1.0914 - val_accuracy: 0.5625 - lr: 5.0000e-04
# Epoch 7/20
# 85/85 [==============================] - 154s 2s/step - loss: 0.5757 - accuracy: 0.7639 - val_loss: 1.0307 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 8/20
# 85/85 [==============================] - ETA: 0s - loss: 0.5637 - accuracy: 0.7682
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 85/85 [==============================] - 155s 2s/step - loss: 0.5637 - accuracy: 0.7682 - val_loss: 1.0816 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 9/20
# 85/85 [==============================] - 161s 2s/step - loss: 0.5378 - accuracy: 0.7793 - val_loss: 1.1624 - val_accuracy: 0.5625 - lr: 2.5000e-04
# Epoch 10/20
# 85/85 [==============================] - 156s 2s/step - loss: 0.5374 - accuracy: 0.7817 - val_loss: 1.1607 - val_accuracy: 0.5833 - lr: 2.5000e-04
# Epoch 11/20
# 85/85 [==============================] - 155s 2s/step - loss: 0.5286 - accuracy: 0.7761 - val_loss: 1.1448 - val_accuracy: 0.6042 - lr: 2.5000e-04
# Epoch 12/20
# 85/85 [==============================] - 156s 2s/step - loss: 0.5175 - accuracy: 0.7867 - val_loss: 1.0943 - val_accuracy: 0.5625 - lr: 2.5000e-04
# Epoch 13/20
# 85/85 [==============================] - 155s 2s/step - loss: 0.5161 - accuracy: 0.7885 - val_loss: 1.1399 - val_accuracy: 0.6042 - lr: 2.5000e-04
# Epoch 14/20
# 85/85 [==============================] - 163s 2s/step - loss: 0.5171 - accuracy: 0.7833 - val_loss: 1.1686 - val_accuracy: 0.6250 - lr: 2.5000e-04
# Epoch 15/20
# 85/85 [==============================] - 163s 2s/step - loss: 0.5041 - accuracy: 0.7911 - val_loss: 1.1539 - val_accuracy: 0.6250 - lr: 2.5000e-04
# Epoch 16/20
# 85/85 [==============================] - 162s 2s/step - loss: 0.5002 - accuracy: 0.7898 - val_loss: 1.1508 - val_accuracy: 0.5833 - lr: 2.5000e-04
# Epoch 17/20
# 85/85 [==============================] - ETA: 0s - loss: 0.4881 - accuracy: 0.7956
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 85/85 [==============================] - 159s 2s/step - loss: 0.4881 - accuracy: 0.7956 - val_loss: 1.1835 - val_accuracy: 0.6042 - lr: 2.5000e-04
# Epoch 18/20
# 85/85 [==============================] - 154s 2s/step - loss: 0.4804 - accuracy: 0.8019 - val_loss: 1.1724 - val_accuracy: 0.5833 - lr: 1.2500e-04
# Epoch 19/20
# 85/85 [==============================] - 155s 2s/step - loss: 0.4632 - accuracy: 0.8126 - val_loss: 1.1965 - val_accuracy: 0.6250 - lr: 1.2500e-04
# Epoch 20/20
# 85/85 [==============================] - ETA: 0s - loss: 0.4658 - accuracy: 0.8068
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 85/85 [==============================] - 155s 2s/step - loss: 0.4658 - accuracy: 0.8068 - val_loss: 1.1617 - val_accuracy: 0.6250 - lr: 1.2500e-04

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# loss, accuracy = model.evaluate(train_ds, verbose=1,)
# loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)
#
# print("Accuracy: ", accuracy)
# print("Validation Accuracy: ",accuracy_v)
# print("Loss: ",loss)
# print("Validation Loss", loss_v)

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
import matplotlib.pyplot as plt
data = dict()

for i in class_names:
  data[i] = []

plt.figure(figsize=(10, 10))
for images, labels in train_ds:
  for i in range(9):
    data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in data:
  data[i] = len(data[i]) 

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.9/dist-packages (0.2.12)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (1.22.4)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.9/dist-packages (from Augmentor) (8.4.0)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FCFC0CBBEB0>: 100%|██████████| 500/500 [00:29<00:00, 17.02 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FCFC0ED6AC0>: 100%|██████████| 500/500 [00:30<00:00, 16.60 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FCFC0CE16A0>: 100%|██████████| 500/500 [00:24<00:00, 20.63 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=833x680 at 0x7FCFC0CEECD0>: 100%|██████████| 500/500 [02:08<00:00,  3.88 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD04F472250>: 100%|██████████| 500/500 [01:49<00:00,  4.57 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FCFC0DE6310>: 100%|██████████| 500/500 [00:25<00:00, 19.94 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FCFC0C7D310>: 100%|██████████| 500/500 [00:51<00:00,  9.74 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD0300512E0>: 100%|██████████| 500/500 [00:23<00:00, 21.32 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FCFC0D49D60>: 100%|██████████| 500/500 [00:24<00:00, 20.32 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
#
.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000402.jpg_cbc606b0-31c0-4d5b-a846-fe3f9e43f863.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010629.jpg_a417d920-b849-4d04-8a51-9b9bceb02b11.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0011121.jpg_dbcd61f2-3892-4d43-92f1-b562cd225674.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010295.jpg_66a68f20-d2fe-42dc-94e1-17f2e1821b86.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010532.jpg_f355f3d2-6898-42a3-b5dc-73b0439eeadf.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0001135.jpg_f9c4c779-da82-4b46-979d-e7fd21157b39.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000519.jpg_a9f9223d-17be-409f-aaab-da16e28f550c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010416.jpg_f70e3e54-11ba-48b5-8ef2-efb5c93324ce.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000400.jpg_5e6d7e6e-00de-42cf-8971-77be742db033.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010809.jpg_5ea694cd-76fd-4fd1-8eee-a6218ffb742c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010555.jpg_255fd352-9aae-4c61-ab68-1b41982b17d3.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0001135.jpg_a9abad6a-e997-4080-89cc-b13e186139a9.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0011181.jpg_38441e96-242a-44a5-8c8d-f04d0b7afbc5.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010036.jpg_3864559c-756d-48e1-a378-48b5af0e69fa.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000167.jpg_fdd15e3e-5d4c-43c7-b7ef-ca1b4c874c86.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000280.jpg_31e97f78-23f0-4cc1-81fd-46010d833045.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0001121.jpg_b71091d2-210e-41d7-847d-296f8734db87.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010209.jpg_b2d8ffc1-ee56-46b6-8a52-0a938ee3381b.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000280.jpg_43349ba6-51ae-4bcc-8086-d5baf65d6e8c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0009890.jpg_e90b47d6-a92f-45dc-a4f3-376427f9af67.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000550.jpg_52ee9c61-c6b4-41a1-8a0b-2238a57a2b68.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010555.jpg_3be90153-64c7-4e3b-b59b-de955786e024.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010478.jpg_8afdf967-0e99-4548-9d25-125e516c96dc.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000312.jpg_76051185-0001-4b4e-88cb-b2cfc503a864.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0010402.jpg_10d3b8b4-9624-439f-9949-50f0cb030cf0.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train/melanoma/output/melanoma_original_ISIC_0000420.jpg_43604f65-43d7-450d-9083-0bb2d718d97f.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# basal cell carcinoma          2500
# actinic keratosis             2500
# dermatofibroma                2454
# melanoma                      2000
# nevus                         1561
# pigmented benign keratosis    1500
# squamous cell carcinoma       1500
# seborrheic keratosis          1500
# vascular lesion               1500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="/content/gdrive/MyDrive/CNN/Skin_cancer_ISIC_The _international_Skin_Imaging_Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 19254 files belonging to 9 classes.
# Using 15404 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 19254 files belonging to 9 classes.
# Using 3850 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_10 (Conv2D)          (None, 180, 180, 32)      9248
#
#  module_wrapper_19 (ModuleWr  (None, 90, 90, 32)       0
#  apper)
#
#  batch_normalization_2 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  module_wrapper_20 (ModuleWr  (None, 90, 90, 32)       0
#  apper)
#
#  conv2d_11 (Conv2D)          (None, 90, 90, 64)        18496
#
#  conv2d_12 (Conv2D)          (None, 90, 90, 64)        36928
#
#  module_wrapper_21 (ModuleWr  (None, 45, 45, 64)       0
#  apper)
#
#  batch_normalization_3 (Batc  (None, 45, 45, 64)       256
#  hNormalization)
#
#  module_wrapper_22 (ModuleWr  (None, 45, 45, 64)       0
#  apper)
#
#  conv2d_13 (Conv2D)          (None, 43, 43, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 43, 43, 128)      512
#  hNormalization)
#
#  module_wrapper_23 (ModuleWr  (None, 21, 21, 128)      0
#  apper)
#
#  module_wrapper_24 (ModuleWr  (None, 21, 21, 128)      0
#  apper)
#
#  module_wrapper_25 (ModuleWr  (None, 56448)            0
#  apper)
#
#  module_wrapper_26 (ModuleWr  (None, 128)              7225472
#  apper)
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  module_wrapper_27 (ModuleWr  (None, 128)              0
#  apper)
#
#  module_wrapper_28 (ModuleWr  (None, 1)                129
#  apper)
#
# =================================================================
# Total params: 7,366,433
# Trainable params: 7,365,729
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
epochs = 30

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/30
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 482/482 [==============================] - 134s 264ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 0.0010
# Epoch 2/30
# 482/482 [==============================] - 124s 254ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 0.0010
# Epoch 3/30
# 482/482 [==============================] - 142s 293ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 0.0010
# Epoch 4/30
# 482/482 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1489
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 482/482 [==============================] - 123s 253ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 0.0010
# Epoch 5/30
# 482/482 [==============================] - 126s 258ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 5.0000e-04
# Epoch 6/30
# 482/482 [==============================] - 125s 256ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 5.0000e-04
# Epoch 7/30
# 482/482 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1489
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 482/482 [==============================] - 126s 259ms/step - loss: 0.0000e+00 - accuracy: 0.1489 - val_loss: 0.0000e+00 - val_accuracy: 0.1512 - lr: 5.0000e-04
# Epoch 8/30
# 350/482 [====================>.........] - ETA: 27s - loss: 0.0000e+00 - accuracy: 0.1479

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %%
The rebalancing of the class played a significant role in mitigating overfitting of the data, resulting in a decrease in loss. However, the approach also resulted in a notable decrease in accuracy.

In the beginning, we experimented without utilizing the ImageDataGenerator, which led to a high degree of overfitting in the data. Subsequently, we implemented dropout and the ImageDataGenerator, which helped to reduce overfitting.

Finally, we incorporated Batch Normalization and Augmentation techniques, which proved to be extremely effective in moving forward.
